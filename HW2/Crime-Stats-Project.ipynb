# %% [markdown]
# ##  Deep Neural Networks Project

# %% [markdown]
# In this project, you will be working with a real-world data set from the Las Vegas Metropolitan Police Department. The dataset  contains information about the reported incidents, including the time and location of the crime, type of incident, and number of persons involved.

# %% [markdown]
# The dataset is downloaded from the public docket at:
# https://opendata-lvmpd.hub.arcgis.com
#
# let's read the csv file and transform the data:

# %%
import torch
import pandas as pd
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
orig_df = pd.read_csv('LVMPD-Stats.csv', parse_dates=['ReportedOn'])

# %%
df = pd.read_csv('LVMPD-Stats.csv', parse_dates=['ReportedOn'],
                 usecols = ['X', 'Y', 'ReportedOn',
                            'Area_Command','NIBRSOffenseCode',
                            'VictimCount' ] )

df['DayOfWeek'] = df['ReportedOn'].dt.day_name()
df['Time' ]     = df['ReportedOn'].dt.hour
df.drop(columns = 'ReportedOn', inplace=True)

# %%
df['X'] = df['X'] 
df['Y'] = df['Y'] 
df['Time'] = pd.factorize(df['Time'])[0]
df['DayOfWeek'] = pd.factorize(df['DayOfWeek'])[0]
df.Area_Command = pd.factorize(df['Area_Command'])[0]
df.VictimCount = pd.factorize(df['VictimCount'])[0]
df.NIBRSOffenseCode = pd.factorize(df['NIBRSOffenseCode'])[0]
df.dropna(inplace=True)

# %%
df= df[['X', 'Y', 'Area_Command', 'NIBRSOffenseCode',
       'DayOfWeek', 'Time','VictimCount']]

# %%
df.values.shape
# Out:
# (275, 7)

# %% [markdown]
# # Goal
# The goal is to build a predictive model that is trained on the following data:
# * latitude and longitude (location)
# * Hour of the day
# * Day of the week
# * Area-of-command code: The police designation of the bureau of the operation.
# * Classification code for the crime committed
#
# The predicted variable is the number of persons involved in the accident.

# %% [markdown]
# ## Task 1
# * print a few rows of the values in the dataframe ``df`` and explain what each column of data means.
# * identify the input and target variables
# * what is the range of values in each column? Do you need to scale, shift or normalize your data?

# %%
df.head()
# Out:
#             X          Y  Area_Command  NIBRSOffenseCode  DayOfWeek  Time  \
# 0 -115.087518  36.216702             0                 0          0     0
# 1 -115.240172  36.189693             1                 1          1     1
# 2 -115.143088  36.181329             2                 1          2     0
# 3 -115.225014  36.117633             3                 1          1     2
# 4 -115.176708  36.095967             4                 1          1     3
#
#    VictimCount
# 0            0
# 1            0
# 2            1
# 3            2
# 4            0

# %% [markdown]
# ## Data Description
#
# ### Columns
#
# 1. **X and Y**: Latitude and longitude coordinates.
# 2. **Area_Command**: The police command area.
# 3. **NIBRSOffenseCode**: Code for the crimes.
# 4. **DayOfWeek**: The day of the week.
# 5. **Time**: The hour of the day.
# 6. **VictimCount**: Number of victims in the incident.
#
# ### Input Variables
#
# - **X (Latitude)**
# - **Y (Longitude)**
# - **Area_Command**
# - **NIBRSOffenseCode**
# - **DayOfWeek**
# - **Time**
#
# ### Target Variable
#
# - **VictimCount**
#
# ### Range of Values in Each Column
#
# - **X (Latitude)**: -114.6255705 to -116.0
# - **Y (Longitude)**: 37.0000000000001 to 35.0684190000001
# - **DayOfWeek**: 0 to 6
# - **Time**: 0 to 23
# - **Area_Command**: 0 to 11
# - **NIBRSOffenseCode**: 0 to 2
# - **VictimCount**: 0 to 6

# %% [markdown]
# ## Task 2
#
# * Create two `DataLoader` objects for training and testing based on the input and output variables. Pick a reasonable batch size and verify the shape of data by iterating over the one dataset and printing the shape of the batched data.

# %%
from sklearn.model_selection import train_test_split


X = df[['X', 'Y', 'Area_Command', 'NIBRSOffenseCode', 'DayOfWeek', 'Time']]
y = df['VictimCount']
from torch.utils.data import TensorDataset

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=100)
print(len(X_train))
batch_size = 70
train_dataset = TensorDataset(torch.Tensor(X_train.values), torch.Tensor(y_train.values))
test_dataset = TensorDataset(torch.Tensor(X_test.values), torch.Tensor(y_test.values))

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

for batch in train_loader:
    inputs, targets = batch
    print("Input shape:", inputs.shape)
    print("Target shape:", targets.shape)
    break
# Out:
# 206
# Input shape: torch.Size([70, 6])
# Target shape: torch.Size([70])

# %% [markdown]
# ## Task 3
# In this task you will try to predict number of crime victims as a **real number**. Therefore the machine learning problem is a **regression** problem.
#
# * Define the proper loss function for this task
# * what should the size of the predicted output be?
# * explain your choice of architecture, including how many layers you will be using
# * define an optimizer for training this model, choose a proper learning rate
# * write a training loop that obtains a batch out of the  training data and calculates the forward and backward passes over the neural network. Call the optimizer to update the weights of the neural network.
# * write a for loop that continues the training over a number of epochs. At the end of each epoch, calculate the ``MSE`` error on the test data and print it.
# * is your model training well? Adjust the learning rate, hidden size of the network, and try different activation functions and number of layers to achieve the best accuracy and report it.

# %%
# The size of the predicted output should be 1. This is because the goal of regression is to predict the number of persons involved in the crime.
#
#  The architecture for regression is a simple feedforward neural network architecture with multiple layers is used.
#
# Input Layer: The input layer has a size of input_size, which is determined by the number of features in the dataset (6 in this case: latitude, longitude, hour of the day, day of the week, area-of-command code, and classification code). The input layer is designed to accept these features.
#
# Hidden Layers: The model includes multiple hidden layers, which is a common practice to capture complex relationships within the data. In this code, there are four hidden layers with the following sizes: 64, 32, 16, and 8.
#
# Output Layer: The output layer is a single neuron since we are predicting the number of persons involved in the crime.
#

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

train_dataset = TensorDataset(torch.Tensor(X_train.values), torch.Tensor(y_train.values))
test_dataset = TensorDataset(torch.Tensor(X_test.values), torch.Tensor(y_test.values))
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

class RegressionModel(nn.Module):
    def __init__(self, input_size):
        super(RegressionModel, self).__init__()
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear (32, 16)
        self.fc4 = nn.Linear(16, 8)
        self.fc5 = nn.Linear(8, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = torch.sigmoid(self.fc4(x))
        x = self.fc5(x)
        return x

input_size = 6
hidden_size = 10
output_size = 1
batch_size = 70
model = RegressionModel(input_size)
criterion = nn.MSELoss()
optimizer = torch.optim.SGD (model.parameters(), lr=0.001)


num_epochs = 500

for epoch in range(num_epochs):
    model.train()
    for batch in train_loader:
        inputs, targets = batch

        predictions = model(inputs)
        target = targets
        target = target.view(-1)

        criterion = nn.MSELoss()

        loss = criterion(predictions.flatten(), target.flatten())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
        test_loss = 0
        for batch in test_loader:
            inputs, targets = batch
            outputs = model(inputs)
            test_loss += criterion(outputs.flatten(), targets.flatten())

    print(f'Epoch [{epoch + 1}/{num_epochs}], Test Loss: {test_loss.item():.4f}')
# Out:
# Epoch [1/500], Test Loss: 1.2271
# Epoch [2/500], Test Loss: 1.1860
# Epoch [3/500], Test Loss: 1.1436
# Epoch [4/500], Test Loss: 1.0989
# Epoch [487/500], Test Loss: 0.9508
# Epoch [488/500], Test Loss: 0.9509
# Epoch [489/500], Test Loss: 0.9510
# Epoch [490/500], Test Loss: 0.9512
# Epoch [491/500], Test Loss: 0.9511
# Epoch [492/500], Test Loss: 0.9511
# Epoch [493/500], Test Loss: 0.9511
# Epoch [494/500], Test Loss: 0.9510
# Epoch [495/500], Test Loss: 0.9511
# Epoch [496/500], Test Loss: 0.9511
# Epoch [497/500], Test Loss: 0.9511
# Epoch [498/500], Test Loss: 0.9510
# Epoch [499/500], Test Loss: 0.9509
# Epoch [500/500], Test Loss: 0.9508

# %% [markdown]
# ## Task 4
#
# In this task, you will try to predict the number of crime victims as a **class number**. Therefore the machine learning problem is a **classification** problem.
#
# * Repeat all the steps in task 3. Specifically, pay attention to the differences with regression.
# * How would you find the number of classes on the output data?
# * How is the architecture different?
# * How is the loss function different?
# * Calculate the Accuracy for test data as the number of correct classified outputs divided by the total number of test data in each epoch. Report it at the end of each epoch
# * Try a few variations of learning rate, hidden dimensions, layers, etc. What is the best accuracy that you can get?

# %%
 # How would you find the number of classes on the output data?
num_classes = len(df['VictimCount'].unique())
print(num_classes)
# Out:
# 7

# %%
# To distinguish between classification and regression tasks and to determine the number of classes, architecture, and loss function differences, let's look at the key distinctions:
#
# Number of Classes:
#
# In classification task, the number of classes is determined by the categories or labels that we are trying to predict. We have 7 classes for classification.
# In regression task, there are no classes. The goal is to predict the number of persons involved in the crime.


# Architecture Differences:
#
# Classification Architecture: In classification, the output layer of the neural network  has a number of neurons equal to the number of classes.
# Regression Architecture: In regression, the output layer  has a single neuron that directly predicts the numeric value.


# Loss Function Differences:
#
# Classification Loss Function: For classification task, we use a categorical cross-entropy loss function. The loss functions measure the difference between the predicted class probabilities and the true class labels.
# Regression Loss Function: For regression task, the mean squared error (MSE) loss function is used. MSE measures the squared difference between the predicted numeric values and the true numeric values.
# In summary, the key differences between classification and regression tasks lie in the number of classes, the architecture of the output layer, and the choice of loss function. These differences reflect the distinct objectives of each task: classification aims to assign data points to predefined categories, while regression aims to predict numeric values.
#
# In summary, the main differences between classification and regression functions are the number of classes, output level architecture, and loss function selection These differences reflect the specific purpose of each function: classification aims to assign data points to predefined classes, while regression aims to predict numeric values

# %%
import torch.nn as nn

class ClassificationModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(ClassificationModel, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, hidden_size)
        self.fc5 = nn.Linear(hidden_size, hidden_size)
        self.fc6 = nn.Linear(hidden_size, hidden_size)
        self.fc7 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.tanh(self.fc3(x))
        x = torch.relu(self.fc4(x))
        x = torch.sigmoid(self.fc5(x))
        x = torch.relu(self.fc6(x))
        x = self.fc7(x)
        return x


batch_size = 70
train_dataset = TensorDataset(torch.Tensor(X_train.values), torch.LongTensor(y_train.values))
test_dataset = TensorDataset(torch.Tensor(X_test.values), torch.LongTensor(y_test.values))
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

output_size = len(df['VictimCount'].unique())
model = ClassificationModel(input_size, hidden_size, output_size)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
num_epochs = 600

for epoch in range(num_epochs):
    model.train()
    for batch in train_loader:
        inputs, targets = batch

        outputs = model(inputs)

        loss = criterion(outputs, targets)

        loss.backward()
        optimizer.step()

    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for batch in test_loader:
            inputs, targets = batch
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()

    accuracy = 100 * correct / total
    print(f'Epoch [{epoch + 1}/{num_epochs}], Test Accuracy: {accuracy:.2f}%')
# Out:
# Epoch [1/600], Test Accuracy: 1.45%
# Epoch [2/600], Test Accuracy: 1.45%
# Epoch [3/600], Test Accuracy: 1.45%
# Epoch [4/600], Test Accuracy: 1.45%
# Epoch [5/600], Test Accuracy: 1.45%
# Epoch [6/600], Test Accuracy: 65.22%
# Epoch [7/600], Test Accuracy: 65.22%
# Epoch [8/600], Test Accuracy: 65.22%
# Epoch [9/600], Test Accuracy: 65.22%
# Epoch [10/600], Test Accuracy: 65.22%
# Epoch [11/600], Test Accuracy: 65.22%
# Epoch [12/600], Test Accuracy: 65.22%
# Epoch [13/600], Test Accuracy: 65.22%
# Epoch [14/600], Test Accuracy: 65.22%
# Epoch [15/600], Test Accuracy: 65.22%
# Epoch [16/600], Test Accuracy: 65.22%
# Epoch [17/600], Test Accuracy: 65.22%
# Epoch [18/600], Test Accuracy: 65.22%
# Epoch [19/600], Test Accuracy: 65.22%
# Epoch [20/600], Test Accuracy: 65.22%
# Epoch [21/600], Test Accuracy: 65.22%
# Epoch [22/600], Test Accuracy: 65.22%
# Epoch [23/600], Test Accuracy: 65.22%
# Epoch [24/600], Test Accuracy: 65.22%
# Epoch [25/600], Test Accuracy: 65.22%
# Epoch [26/600], Test Accuracy: 65.22%
# Epoch [27/600], Test Accuracy: 65.22%
# Epoch [28/600], Test Accuracy: 65.22%
# Epoch [29/600], Test Accuracy: 65.22%
# Epoch [30/600], Test Accuracy: 65.22%
# Epoch [31/600], Test Accuracy: 65.22%
# Epoch [32/600], Test Accuracy: 65.22%
# Epoch [33/600], Test Accuracy: 65.22%
# Epoch [34/600], Test Accuracy: 65.22%
# Epoch [35/600], Test Accuracy: 65.22%
# Epoch [36/600], Test Accuracy: 65.22%
# Epoch [37/600], Test Accuracy: 65.22%
# Epoch [38/600], Test Accuracy: 65.22%
# Epoch [39/600], Test Accuracy: 65.22%
# Epoch [40/600], Test Accuracy: 65.22%
# Epoch [41/600], Test Accuracy: 65.22%
# Epoch [42/600], Test Accuracy: 65.22%
# Epoch [43/600], Test Accuracy: 65.22%
# Epoch [44/600], Test Accuracy: 65.22%
# Epoch [45/600], Test Accuracy: 65.22%
# Epoch [46/600], Test Accuracy: 65.22%
# Epoch [47/600], Test Accuracy: 65.22%
# Epoch [48/600], Test Accuracy: 65.22%
# Epoch [49/600], Test Accuracy: 65.22%
# Epoch [50/600], Test Accuracy: 65.22%
# Epoch [51/600], Test Accuracy: 65.22%
# Epoch [52/600], Test Accuracy: 65.22%
# Epoch [53/600], Test Accuracy: 65.22%
# Epoch [54/600], Test Accuracy: 65.22%
# Epoch [55/600], Test Accuracy: 65.22%
# Epoch [56/600], Test Accuracy: 65.22%
# Epoch [57/600], Test Accuracy: 65.22%
# Epoch [58/600], Test Accuracy: 65.22%
# Epoch [59/600], Test Accuracy: 65.22%
# Epoch [60/600], Test Accuracy: 65.22%
# Epoch [61/600], Test Accuracy: 65.22%
# Epoch [62/600], Test Accuracy: 65.22%
# Epoch [63/600], Test Accuracy: 65.22%
# Epoch [64/600], Test Accuracy: 65.22%
# Epoch [65/600], Test Accuracy: 65.22%
# Epoch [66/600], Test Accuracy: 65.22%
# Epoch [67/600], Test Accuracy: 65.22%
# Epoch [68/600], Test Accuracy: 65.22%
# Epoch [69/600], Test Accuracy: 65.22%
# Epoch [70/600], Test Accuracy: 65.22%
# Epoch [71/600], Test Accuracy: 65.22%
# Epoch [72/600], Test Accuracy: 65.22%
# Epoch [73/600], Test Accuracy: 65.22%
# Epoch [74/600], Test Accuracy: 65.22%
# Epoch [75/600], Test Accuracy: 65.22%
# Epoch [76/600], Test Accuracy: 65.22%
# Epoch [77/600], Test Accuracy: 23.19%
# Epoch [78/600], Test Accuracy: 23.19%
# Epoch [79/600], Test Accuracy: 23.19%
# Epoch [80/600], Test Accuracy: 23.19%
# Epoch [81/600], Test Accuracy: 23.19%
# Epoch [82/600], Test Accuracy: 23.19%
# Epoch [83/600], Test Accuracy: 23.19%
# Epoch [84/600], Test Accuracy: 23.19%
# Epoch [85/600], Test Accuracy: 23.19%
# Epoch [86/600], Test Accuracy: 23.19%
# Epoch [87/600], Test Accuracy: 23.19%
# Epoch [88/600], Test Accuracy: 23.19%
# Epoch [89/600], Test Accuracy: 23.19%
# Epoch [90/600], Test Accuracy: 23.19%
# Epoch [91/600], Test Accuracy: 23.19%
# Epoch [92/600], Test Accuracy: 23.19%
# Epoch [93/600], Test Accuracy: 23.19%
# Epoch [94/600], Test Accuracy: 23.19%
# Epoch [95/600], Test Accuracy: 23.19%
# Epoch [96/600], Test Accuracy: 23.19%
# Epoch [97/600], Test Accuracy: 23.19%
# Epoch [98/600], Test Accuracy: 23.19%
# Epoch [99/600], Test Accuracy: 23.19%
# Epoch [100/600], Test Accuracy: 23.19%
# Epoch [101/600], Test Accuracy: 23.19%
# Epoch [102/600], Test Accuracy: 23.19%
# Epoch [103/600], Test Accuracy: 23.19%
# Epoch [104/600], Test Accuracy: 23.19%
# Epoch [105/600], Test Accuracy: 23.19%
# Epoch [106/600], Test Accuracy: 23.19%
# Epoch [107/600], Test Accuracy: 23.19%
# Epoch [108/600], Test Accuracy: 23.19%
# Epoch [109/600], Test Accuracy: 23.19%
# Epoch [110/600], Test Accuracy: 23.19%
# Epoch [111/600], Test Accuracy: 23.19%
# Epoch [112/600], Test Accuracy: 23.19%
# Epoch [113/600], Test Accuracy: 65.22%
# Epoch [114/600], Test Accuracy: 65.22%
# Epoch [115/600], Test Accuracy: 65.22%
# Epoch [116/600], Test Accuracy: 65.22%
# Epoch [117/600], Test Accuracy: 65.22%
# Epoch [118/600], Test Accuracy: 65.22%
# Epoch [119/600], Test Accuracy: 65.22%
# Epoch [120/600], Test Accuracy: 65.22%
# Epoch [121/600], Test Accuracy: 65.22%
# Epoch [122/600], Test Accuracy: 65.22%
# Epoch [123/600], Test Accuracy: 65.22%
# Epoch [124/600], Test Accuracy: 65.22%
# Epoch [125/600], Test Accuracy: 65.22%
# Epoch [126/600], Test Accuracy: 65.22%
# Epoch [127/600], Test Accuracy: 65.22%
# Epoch [128/600], Test Accuracy: 65.22%
# Epoch [129/600], Test Accuracy: 65.22%
# Epoch [130/600], Test Accuracy: 65.22%
# Epoch [131/600], Test Accuracy: 65.22%
# Epoch [132/600], Test Accuracy: 65.22%
# Epoch [133/600], Test Accuracy: 65.22%
# Epoch [134/600], Test Accuracy: 65.22%
# Epoch [135/600], Test Accuracy: 65.22%
# Epoch [136/600], Test Accuracy: 65.22%
# Epoch [137/600], Test Accuracy: 65.22%
# Epoch [138/600], Test Accuracy: 65.22%
# Epoch [139/600], Test Accuracy: 65.22%
# Epoch [140/600], Test Accuracy: 65.22%
# Epoch [141/600], Test Accuracy: 65.22%
# Epoch [142/600], Test Accuracy: 65.22%
# Epoch [143/600], Test Accuracy: 65.22%
# Epoch [144/600], Test Accuracy: 65.22%
# Epoch [145/600], Test Accuracy: 65.22%
# Epoch [146/600], Test Accuracy: 65.22%
# Epoch [147/600], Test Accuracy: 65.22%
# Epoch [148/600], Test Accuracy: 65.22%
# Epoch [149/600], Test Accuracy: 65.22%
# Epoch [150/600], Test Accuracy: 65.22%
# Epoch [151/600], Test Accuracy: 65.22%
# Epoch [152/600], Test Accuracy: 65.22%
# Epoch [153/600], Test Accuracy: 65.22%
# Epoch [154/600], Test Accuracy: 65.22%
# Epoch [155/600], Test Accuracy: 65.22%
# Epoch [156/600], Test Accuracy: 65.22%
# Epoch [157/600], Test Accuracy: 65.22%
# Epoch [158/600], Test Accuracy: 65.22%
# Epoch [159/600], Test Accuracy: 65.22%
# Epoch [160/600], Test Accuracy: 65.22%
# Epoch [161/600], Test Accuracy: 65.22%
# Epoch [162/600], Test Accuracy: 65.22%
# Epoch [163/600], Test Accuracy: 65.22%
# Epoch [164/600], Test Accuracy: 65.22%
# Epoch [165/600], Test Accuracy: 65.22%
# Epoch [166/600], Test Accuracy: 23.19%
# Epoch [167/600], Test Accuracy: 23.19%
# Epoch [168/600], Test Accuracy: 23.19%
# Epoch [169/600], Test Accuracy: 23.19%
# Epoch [170/600], Test Accuracy: 23.19%
# Epoch [171/600], Test Accuracy: 23.19%
# Epoch [172/600], Test Accuracy: 23.19%
# Epoch [173/600], Test Accuracy: 23.19%
# Epoch [174/600], Test Accuracy: 23.19%
# Epoch [175/600], Test Accuracy: 23.19%
# Epoch [176/600], Test Accuracy: 23.19%
# Epoch [177/600], Test Accuracy: 23.19%
# Epoch [178/600], Test Accuracy: 23.19%
# Epoch [179/600], Test Accuracy: 23.19%
# Epoch [180/600], Test Accuracy: 23.19%
# Epoch [181/600], Test Accuracy: 23.19%
# Epoch [182/600], Test Accuracy: 23.19%
# Epoch [183/600], Test Accuracy: 23.19%
# Epoch [184/600], Test Accuracy: 23.19%
# Epoch [185/600], Test Accuracy: 23.19%
# Epoch [186/600], Test Accuracy: 23.19%
# Epoch [187/600], Test Accuracy: 23.19%
# Epoch [188/600], Test Accuracy: 23.19%
# Epoch [189/600], Test Accuracy: 23.19%
# Epoch [190/600], Test Accuracy: 23.19%
# Epoch [191/600], Test Accuracy: 23.19%
# Epoch [192/600], Test Accuracy: 23.19%
# Epoch [193/600], Test Accuracy: 23.19%
# Epoch [194/600], Test Accuracy: 23.19%
# Epoch [195/600], Test Accuracy: 23.19%
# Epoch [196/600], Test Accuracy: 23.19%
# Epoch [197/600], Test Accuracy: 23.19%
# Epoch [198/600], Test Accuracy: 23.19%
# Epoch [199/600], Test Accuracy: 23.19%
# Epoch [200/600], Test Accuracy: 23.19%
# Epoch [201/600], Test Accuracy: 23.19%
# Epoch [202/600], Test Accuracy: 23.19%
# Epoch [203/600], Test Accuracy: 23.19%
# Epoch [204/600], Test Accuracy: 23.19%
# Epoch [205/600], Test Accuracy: 23.19%
# Epoch [206/600], Test Accuracy: 23.19%
# Epoch [207/600], Test Accuracy: 23.19%
# Epoch [208/600], Test Accuracy: 23.19%
# Epoch [209/600], Test Accuracy: 23.19%
# Epoch [210/600], Test Accuracy: 23.19%
# Epoch [211/600], Test Accuracy: 23.19%
# Epoch [212/600], Test Accuracy: 23.19%
# Epoch [213/600], Test Accuracy: 23.19%
# Epoch [214/600], Test Accuracy: 23.19%
# Epoch [215/600], Test Accuracy: 23.19%
# Epoch [216/600], Test Accuracy: 23.19%
# Epoch [217/600], Test Accuracy: 23.19%
# Epoch [218/600], Test Accuracy: 23.19%
# Epoch [219/600], Test Accuracy: 23.19%
# Epoch [220/600], Test Accuracy: 23.19%
# Epoch [221/600], Test Accuracy: 23.19%
# Epoch [222/600], Test Accuracy: 23.19%
# Epoch [223/600], Test Accuracy: 23.19%
# Epoch [224/600], Test Accuracy: 23.19%
# Epoch [225/600], Test Accuracy: 23.19%
# Epoch [226/600], Test Accuracy: 23.19%
# Epoch [227/600], Test Accuracy: 65.22%
# Epoch [228/600], Test Accuracy: 65.22%
# Epoch [229/600], Test Accuracy: 65.22%
# Epoch [230/600], Test Accuracy: 65.22%
# Epoch [231/600], Test Accuracy: 65.22%
# Epoch [232/600], Test Accuracy: 65.22%
# Epoch [233/600], Test Accuracy: 65.22%
# Epoch [234/600], Test Accuracy: 65.22%
# Epoch [235/600], Test Accuracy: 65.22%
# Epoch [236/600], Test Accuracy: 65.22%
# Epoch [237/600], Test Accuracy: 65.22%
# Epoch [238/600], Test Accuracy: 65.22%
# Epoch [239/600], Test Accuracy: 65.22%
# Epoch [240/600], Test Accuracy: 65.22%
# Epoch [241/600], Test Accuracy: 65.22%
# Epoch [242/600], Test Accuracy: 65.22%
# Epoch [243/600], Test Accuracy: 65.22%
# Epoch [244/600], Test Accuracy: 65.22%
# Epoch [245/600], Test Accuracy: 65.22%
# Epoch [246/600], Test Accuracy: 65.22%
# Epoch [247/600], Test Accuracy: 65.22%
# Epoch [248/600], Test Accuracy: 65.22%
# Epoch [249/600], Test Accuracy: 65.22%
# Epoch [250/600], Test Accuracy: 65.22%
# Epoch [251/600], Test Accuracy: 65.22%
# Epoch [252/600], Test Accuracy: 65.22%
# Epoch [253/600], Test Accuracy: 65.22%
# Epoch [254/600], Test Accuracy: 65.22%
# Epoch [255/600], Test Accuracy: 65.22%
# Epoch [256/600], Test Accuracy: 65.22%
# Epoch [257/600], Test Accuracy: 65.22%
# Epoch [258/600], Test Accuracy: 65.22%
# Epoch [259/600], Test Accuracy: 65.22%
# Epoch [260/600], Test Accuracy: 65.22%
# Epoch [261/600], Test Accuracy: 65.22%
# Epoch [262/600], Test Accuracy: 65.22%
# Epoch [263/600], Test Accuracy: 65.22%
# Epoch [264/600], Test Accuracy: 65.22%
# Epoch [265/600], Test Accuracy: 65.22%
# Epoch [266/600], Test Accuracy: 65.22%
# Epoch [267/600], Test Accuracy: 65.22%
# Epoch [268/600], Test Accuracy: 65.22%
# Epoch [269/600], Test Accuracy: 65.22%
# Epoch [270/600], Test Accuracy: 65.22%
# Epoch [271/600], Test Accuracy: 65.22%
# Epoch [272/600], Test Accuracy: 65.22%
# Epoch [273/600], Test Accuracy: 65.22%
# Epoch [274/600], Test Accuracy: 65.22%
# Epoch [275/600], Test Accuracy: 65.22%
# Epoch [276/600], Test Accuracy: 65.22%
# Epoch [277/600], Test Accuracy: 65.22%
# Epoch [278/600], Test Accuracy: 65.22%
# Epoch [279/600], Test Accuracy: 65.22%
# Epoch [280/600], Test Accuracy: 65.22%
# Epoch [281/600], Test Accuracy: 65.22%
# Epoch [282/600], Test Accuracy: 65.22%
# Epoch [283/600], Test Accuracy: 65.22%
# Epoch [284/600], Test Accuracy: 65.22%
# Epoch [285/600], Test Accuracy: 65.22%
# Epoch [286/600], Test Accuracy: 65.22%
# Epoch [287/600], Test Accuracy: 65.22%
# Epoch [288/600], Test Accuracy: 65.22%
# Epoch [289/600], Test Accuracy: 65.22%
# Epoch [290/600], Test Accuracy: 65.22%
# Epoch [291/600], Test Accuracy: 65.22%
# Epoch [292/600], Test Accuracy: 65.22%
# Epoch [293/600], Test Accuracy: 65.22%
# Epoch [294/600], Test Accuracy: 65.22%
# Epoch [295/600], Test Accuracy: 65.22%
# Epoch [296/600], Test Accuracy: 65.22%
# Epoch [297/600], Test Accuracy: 65.22%
# Epoch [298/600], Test Accuracy: 65.22%
# Epoch [299/600], Test Accuracy: 65.22%
# Epoch [300/600], Test Accuracy: 65.22%
# Epoch [301/600], Test Accuracy: 65.22%
# Epoch [302/600], Test Accuracy: 65.22%
# Epoch [303/600], Test Accuracy: 65.22%
# Epoch [304/600], Test Accuracy: 65.22%
# Epoch [305/600], Test Accuracy: 65.22%
# Epoch [306/600], Test Accuracy: 65.22%
# Epoch [307/600], Test Accuracy: 65.22%
# Epoch [308/600], Test Accuracy: 65.22%
# Epoch [309/600], Test Accuracy: 65.22%
# Epoch [310/600], Test Accuracy: 65.22%
# Epoch [311/600], Test Accuracy: 65.22%
# Epoch [312/600], Test Accuracy: 65.22%
# Epoch [313/600], Test Accuracy: 65.22%
# Epoch [314/600], Test Accuracy: 65.22%
# Epoch [315/600], Test Accuracy: 65.22%
# Epoch [316/600], Test Accuracy: 65.22%
# Epoch [317/600], Test Accuracy: 65.22%
# Epoch [318/600], Test Accuracy: 65.22%
# Epoch [319/600], Test Accuracy: 65.22%
# Epoch [320/600], Test Accuracy: 65.22%
# Epoch [321/600], Test Accuracy: 65.22%
# Epoch [322/600], Test Accuracy: 65.22%
# Epoch [323/600], Test Accuracy: 65.22%
# Epoch [324/600], Test Accuracy: 65.22%
# Epoch [325/600], Test Accuracy: 65.22%
# Epoch [326/600], Test Accuracy: 65.22%
# Epoch [327/600], Test Accuracy: 65.22%
# Epoch [328/600], Test Accuracy: 65.22%
# Epoch [329/600], Test Accuracy: 65.22%
# Epoch [330/600], Test Accuracy: 65.22%
# Epoch [331/600], Test Accuracy: 65.22%
# Epoch [332/600], Test Accuracy: 65.22%
# Epoch [333/600], Test Accuracy: 65.22%
# Epoch [334/600], Test Accuracy: 65.22%
# Epoch [335/600], Test Accuracy: 65.22%
# Epoch [336/600], Test Accuracy: 65.22%
# Epoch [337/600], Test Accuracy: 65.22%
# Epoch [338/600], Test Accuracy: 65.22%
# Epoch [339/600], Test Accuracy: 65.22%
# Epoch [340/600], Test Accuracy: 65.22%
# Epoch [341/600], Test Accuracy: 65.22%
# Epoch [342/600], Test Accuracy: 65.22%
# Epoch [343/600], Test Accuracy: 65.22%
# Epoch [344/600], Test Accuracy: 65.22%
# Epoch [345/600], Test Accuracy: 65.22%
# Epoch [346/600], Test Accuracy: 65.22%
# Epoch [347/600], Test Accuracy: 65.22%
# Epoch [348/600], Test Accuracy: 65.22%
# Epoch [349/600], Test Accuracy: 65.22%
# Epoch [350/600], Test Accuracy: 65.22%
# Epoch [351/600], Test Accuracy: 65.22%
# Epoch [352/600], Test Accuracy: 65.22%
# Epoch [353/600], Test Accuracy: 65.22%
# Epoch [354/600], Test Accuracy: 65.22%
# Epoch [355/600], Test Accuracy: 65.22%
# Epoch [356/600], Test Accuracy: 65.22%
# Epoch [357/600], Test Accuracy: 65.22%
# Epoch [358/600], Test Accuracy: 65.22%
# Epoch [359/600], Test Accuracy: 65.22%
# Epoch [360/600], Test Accuracy: 65.22%
# Epoch [361/600], Test Accuracy: 65.22%
# Epoch [362/600], Test Accuracy: 65.22%
# Epoch [363/600], Test Accuracy: 65.22%
# Epoch [364/600], Test Accuracy: 65.22%
# Epoch [365/600], Test Accuracy: 65.22%
# Epoch [366/600], Test Accuracy: 65.22%
# Epoch [367/600], Test Accuracy: 65.22%
# Epoch [368/600], Test Accuracy: 65.22%
# Epoch [369/600], Test Accuracy: 65.22%
# Epoch [370/600], Test Accuracy: 65.22%
# Epoch [371/600], Test Accuracy: 65.22%
# Epoch [372/600], Test Accuracy: 65.22%
# Epoch [373/600], Test Accuracy: 65.22%
# Epoch [374/600], Test Accuracy: 65.22%
# Epoch [375/600], Test Accuracy: 65.22%
# Epoch [376/600], Test Accuracy: 65.22%
# Epoch [377/600], Test Accuracy: 65.22%
# Epoch [378/600], Test Accuracy: 65.22%
# Epoch [379/600], Test Accuracy: 65.22%
# Epoch [380/600], Test Accuracy: 65.22%
# Epoch [381/600], Test Accuracy: 65.22%
# Epoch [382/600], Test Accuracy: 65.22%
# Epoch [383/600], Test Accuracy: 65.22%
# Epoch [384/600], Test Accuracy: 65.22%
# Epoch [385/600], Test Accuracy: 65.22%
# Epoch [386/600], Test Accuracy: 65.22%
# Epoch [387/600], Test Accuracy: 65.22%
# Epoch [388/600], Test Accuracy: 65.22%
# Epoch [389/600], Test Accuracy: 65.22%
# Epoch [390/600], Test Accuracy: 65.22%
# Epoch [391/600], Test Accuracy: 65.22%
# Epoch [392/600], Test Accuracy: 65.22%
# Epoch [393/600], Test Accuracy: 65.22%
# Epoch [394/600], Test Accuracy: 65.22%
# Epoch [395/600], Test Accuracy: 65.22%
# Epoch [396/600], Test Accuracy: 65.22%
# Epoch [397/600], Test Accuracy: 65.22%
# Epoch [398/600], Test Accuracy: 65.22%
# Epoch [399/600], Test Accuracy: 65.22%
# Epoch [400/600], Test Accuracy: 65.22%
# Epoch [401/600], Test Accuracy: 65.22%
# Epoch [402/600], Test Accuracy: 65.22%
# Epoch [403/600], Test Accuracy: 65.22%
# Epoch [404/600], Test Accuracy: 65.22%
# Epoch [405/600], Test Accuracy: 65.22%
# Epoch [406/600], Test Accuracy: 65.22%
# Epoch [407/600], Test Accuracy: 65.22%
# Epoch [408/600], Test Accuracy: 65.22%
# Epoch [409/600], Test Accuracy: 65.22%
# Epoch [410/600], Test Accuracy: 65.22%
# Epoch [411/600], Test Accuracy: 65.22%
# Epoch [412/600], Test Accuracy: 65.22%
# Epoch [413/600], Test Accuracy: 65.22%
# Epoch [414/600], Test Accuracy: 65.22%
# Epoch [415/600], Test Accuracy: 65.22%
# Epoch [416/600], Test Accuracy: 65.22%
# Epoch [417/600], Test Accuracy: 23.19%
# Epoch [418/600], Test Accuracy: 23.19%
# Epoch [419/600], Test Accuracy: 23.19%
# Epoch [420/600], Test Accuracy: 23.19%
# Epoch [421/600], Test Accuracy: 23.19%
# Epoch [422/600], Test Accuracy: 23.19%
# Epoch [423/600], Test Accuracy: 23.19%
# Epoch [424/600], Test Accuracy: 23.19%
# Epoch [425/600], Test Accuracy: 23.19%
# Epoch [426/600], Test Accuracy: 23.19%
# Epoch [427/600], Test Accuracy: 23.19%
# Epoch [428/600], Test Accuracy: 23.19%
# Epoch [429/600], Test Accuracy: 23.19%
# Epoch [430/600], Test Accuracy: 23.19%
# Epoch [431/600], Test Accuracy: 23.19%
# Epoch [432/600], Test Accuracy: 23.19%
# Epoch [433/600], Test Accuracy: 23.19%
# Epoch [434/600], Test Accuracy: 23.19%
# Epoch [435/600], Test Accuracy: 23.19%
# Epoch [436/600], Test Accuracy: 23.19%
# Epoch [437/600], Test Accuracy: 23.19%
# Epoch [438/600], Test Accuracy: 23.19%
# Epoch [439/600], Test Accuracy: 23.19%
# Epoch [440/600], Test Accuracy: 23.19%
# Epoch [441/600], Test Accuracy: 23.19%
# Epoch [568/600], Test Accuracy: 23.19%
# Epoch [569/600], Test Accuracy: 23.19%
# Epoch [570/600], Test Accuracy: 23.19%
# Epoch [571/600], Test Accuracy: 23.19%
# Epoch [572/600], Test Accuracy: 23.19%
# Epoch [573/600], Test Accuracy: 23.19%
# Epoch [574/600], Test Accuracy: 23.19%
# Epoch [575/600], Test Accuracy: 23.19%
# Epoch [576/600], Test Accuracy: 23.19%
# Epoch [577/600], Test Accuracy: 23.19%
# Epoch [578/600], Test Accuracy: 23.19%
# Epoch [579/600], Test Accuracy: 23.19%
# Epoch [580/600], Test Accuracy: 23.19%
# Epoch [581/600], Test Accuracy: 23.19%
# Epoch [582/600], Test Accuracy: 23.19%
# Epoch [583/600], Test Accuracy: 23.19%
# Epoch [584/600], Test Accuracy: 23.19%
# Epoch [585/600], Test Accuracy: 23.19%
# Epoch [586/600], Test Accuracy: 23.19%
# Epoch [587/600], Test Accuracy: 23.19%
# Epoch [588/600], Test Accuracy: 23.19%
# Epoch [589/600], Test Accuracy: 23.19%
# Epoch [590/600], Test Accuracy: 23.19%
# Epoch [591/600], Test Accuracy: 23.19%
# Epoch [592/600], Test Accuracy: 23.19%
# Epoch [593/600], Test Accuracy: 23.19%
# Epoch [594/600], Test Accuracy: 23.19%
# Epoch [595/600], Test Accuracy: 65.22%
# Epoch [596/600], Test Accuracy: 65.22%
# Epoch [597/600], Test Accuracy: 65.22%
# Epoch [598/600], Test Accuracy: 65.22%
# Epoch [599/600], Test Accuracy: 65.22%
# Epoch [600/600], Test Accuracy: 65.22%

# %% [markdown]
# ## Task 5

# %% [markdown]
# ### Reflect on your results
#
# * Write a paragraph about your experience with tasks 3 and 4. How do you compare the results? Which one worked better? Why?
# * Write a piece of code that finds an example of a  miss-classification. Calculate the probabilities for the output classes and plot them in a bar chart. Also, indicate what is the correct class label.

# %%
# Task 3 (Regression):
# In Task 3, we trained a regression model to predict the number of crime victims as a real number. The loss decreased over epochs, indicating that the model learned to minimize the mean squared error (MSE) loss on the test data. The test loss values seem relatively stable over the training period. However, it's crucial to evaluate the model's performance in terms of the MSE error on the test data to assess its predictive accuracy.
#
# Task 4 (Classification):
# In Task 4, you converted the problem into a classification task by predicting the number of crime victims as a class number. The test accuracy values indicate the model's ability to correctly classify the number of crime victims. The accuracy values vary over epochs, showing fluctuations. The highest test accuracy achieved is around 63.77%, suggesting a moderate level of classification performance. However, it's essential to interpret the results based on the specific problem's requirements.
#
# Comparing the Results:
# The choice between regression and classification depends on the problem's nature and objectives. If you need to predict crime victim counts as real numbers, Task 3 is more appropriate. If you want to categorize the counts into classes, Task 4 fits better. The results indicate that classification achieved higher accuracy, but the evaluation metric should align with your task goals.

#
#
# In tasks 3 and 4, a regression model is used in task 3 and a classification model in task 4. The regression model aims to predict the number of persons involved in an accident, while the classification model is designed to classify incidents based on some criteria. The results in both cases are shown in terms of loss for regression and accuracy for classification.
#
# In task 3 (regression), the model achieved a relatively low test loss, which indicates that it is performing well in predicting the number of persons involved in accidents. A lower test loss suggests that the model's predictions are closer to the actual values, demonstrating the effectiveness of the regression model.
#
# In task 4 (classification), the model achieved a test accuracy of 65.22%. This means that the classification model correctly predicted the category of the incidents in about 65.22% of the cases.
#
# Comparing the results, it's important to note that the two tasks have different objectives. In task 3, we are dealing with a regression problem where the model predicts a continuous numerical value, and the low test loss indicates that it's effective in this regard. In task 4, we have a classification problem, and the accuracy of 65.22% shows that the model is making accurate category predictions. Both the tasks wew not able to predict accurately because data is not suitable for building a predictive model.
#     Missing Data: There are missing values in the dataset, which can lead to biased or inaccurate predictions. For example, some rows do not have a value for the "VictimCount" column.
#     The dataset only includes a few features, such as location, time of day, day of the week, and crime classification. This limited set of features may not be enough to accurately predict crime.
# To build a more accurate predictive model, better data is needed. This could include:
# More Complete Data: A dataset with fewer missing values would be more accurate and less biased.
# Consistent Data: A dataset with consistent formatting and naming conventions would be easier to work with and less prone to errors.
# More Features: A dataset with more features, such as weather conditions, demographics, and historical crime data, would provide more context and improve the accuracy of the predictive model.

# %%
import matplotlib.pyplot as plt

misclassified_example = None
for inputs, true_labels in test_loader:
    outputs = model(inputs)
    predicted_labels = torch.argmax(outputs, dim=1)

    for i in range(len(true_labels)):
        if predicted_labels[i].item() != true_labels[i].item():
            misclassified_example = (inputs[i], true_labels[i], predicted_labels[i])
            break

    if misclassified_example:
        break

if misclassified_example:
    input, true_label, predicted_label = misclassified_example
    class_probabilities = torch.softmax(outputs, dim=1)[0].detach().numpy()

    class_labels = range(output_size)
    plt.bar(class_labels, class_probabilities, tick_label=class_labels)
    plt.title("Class Probabilities for Misclassified Example")
    plt.xlabel("Class Label")
    plt.ylabel("Probability")
    plt.show()

# %% [markdown]
# ## Task 6: Exploring the patterns in raw data
#
# * Plot the crime incidents as a `scatter` plot using the corrdinates. Use the color property of each datapoint to indicate the day of the week. Is there a pattern in the plot?
# * Now make a new scatter plot and use the color property of each datapoint to indicate the number of persons involved in the incident. Is there a pattern here?
# * use numpy (or pandas if you like) to sort the number of crimes reported by the day of the week. What days are most frequent?

# %%
plt.scatter(df['X'], df['Y'], c=df['DayOfWeek'].values, cmap='viridis')
plt.title('Crime Incidents by Location and Day of the Week')
plt.xlabel('Longitude (X)')
plt.ylabel('Latitude (Y)')
plt.colorbar(label='Day of the Week')
plt.show()

# Create a scatter plot to indicate the number of persons involved in each incident
plt.scatter(df['X'], df['Y'], c=df['VictimCount'].values, cmap='viridis')
plt.title('Crime Incidents by Location and Number of Persons Involved')
plt.xlabel('Longitude (X)')
plt.ylabel('Latitude (Y)')
plt.colorbar(label='Number of Persons Involved')
plt.show()

# Sort the number of crimes reported by day of the week
day_counts = df['DayOfWeek'].value_counts().reset_index()
day_counts.columns = ['DayOfWeek', 'Count']
day_counts = day_counts.sort_values(by='DayOfWeek')
print(day_counts)
# Out:
#    DayOfWeek  Count
# 3          0     40
# 4          1     37
# 5          2     32
# 1          3     44
# 0          4     51
# 2          5     43
# 6          6     28
